# %%
arquivo = "../corretor-master/artigos.txt"
with open(arquivo,"r", encoding="utf8") as f:
    artigos = f.read()

# %%
print(artigos[:500])
# Out:
# imagem
#
# Temos a seguinte classe que representa um usuário no nosso sistema:
#
# java
#
# Para salvar um novo usuário, várias validações são feitas, como por exemplo: Ver se o nome só contém letras, [**o CPF só números**] e ver se o usuário possui no mínimo 18 anos. Veja o método que faz essa validação:
#
# java
#
# Suponha agora que eu tenha outra classe, a classe `Produto`, que contém um atributo nome e eu quero fazer a mesma validação que fiz para o nome do usuário: Ver se só contém letras. E aí? Vou

# %%
len(artigos)
# Out:
# 2605046

# %%
len("Óla")
# Out:
# 3

# %%
len("Ana")
# Out:
# 3

# %%
texto_exemplo = "Olá, tudo bem?"
tokens = texto_exemplo.split()
tokens
# Out:
# ['Olá,', 'tudo', 'bem?']

# %%
len(tokens)
# Out:
# 3

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ramon\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
palavras_separadas = nltk.tokenize.word_tokenize(texto_exemplo)
palavras_separadas
# Out:
# ['Olá', ',', 'tudo', 'bem', '?']

# %%
len(palavras_separadas)
# Out:
# 5

# %%
'palavras'.isalpha()
# Out:
# True

# %%
'palavras1'.isalpha()
# Out:
# False

# %%
'?'.isalpha()
# Out:
# False

# %%
def separa_palavras(lista_tokens):
    lista_palavras = []
    for token in lista_tokens:
        if token.isalpha():
            lista_palavras.append(token)
    return lista_palavras

# %%
separa_palavras(palavras_separadas)
# Out:
# ['Olá', 'tudo', 'bem']

# %%
lista_tokens = nltk.tokenize.word_tokenize(artigos)
lista_palavras = separa_palavras(lista_tokens)

# %%
('O número de palavras do conjunto é {}'.format(len(lista_palavras)))
# Out:
# 'O número de palavras do conjunto é 403031'

# %%
print(lista_palavras[:5])
# Out:
# ['imagem', 'Temos', 'a', 'seguinte', 'classe']

# %%
def normalizacao(lista_palavras):
    lista_normalizada = []
    for palavra in lista_palavras:
        lista_normalizada.append(palavra.lower())
    return lista_normalizada

# %%
lista_normalizada = normalizacao(lista_palavras)
lista_normalizada[:5]
# Out:
# ['imagem', 'temos', 'a', 'seguinte', 'classe']

# %%
set([1,2,3,3,3,3,4,5,6])
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set(lista_normalizada)
# Out:
# {'gráfico',
#  'verba',
#  'uuid',
#  'menor',
#  'megabits',
#  'prestador',
#  'visualizarmos',
#  'databases',
#  'contêm',
#  'jony',
#  'reproduzir',
#  'reformulamos',
#  'aterrisagem',
#  'xlabel',
#  'storage',
#  'compreendemos',
#  'encontramos',
#  'amanhã',
#  'kurt',
#  'monstrinho',
#  'guis',
#  'sujar',
#  'marcadas',
#  'having',
#  'pmes',
#  'enxutas',
#  'adotados',
#  'lato',
#  'temporary',
#  'aritméticas',
#  'especificar',
#  'sumário',
#  'freela',
#  'referem',
#  'ultrapassam',
#  'retornamos',
#  'pen',
#  'aem',
#  'amadas',
#  'empacotar',
#  'configuração',
#  'válida',
#  'desenvolvem',
#  'parodiando',
#  'obrigatoriedade',
#  'rfc',
#  'feature',
#  'inclusive',
#  'especialização',
#  'osição',
#  'prática',
#  'maneiro',
#  'transformados',
#  'desagradável',
#  'exception',
#  'juntando',
#  'repetitivo',
#  'há',
#  'msn',
#  'emulador',
#  'quebraria',
#  'forçará',
#  'titulo',
#  'entitymanager',
#  'instante',
#  'bayes',
#  'resolva',
# ...

# %%
len(set(lista_normalizada))
# Out:
# 18464

# %%
palavra_exemplo = 'lgica'

# %%
def insere_letras(fatias):
    novas_palavras = []
    letras = 'abcdefghijklmnopqrstuvwxyzàáâãèéêìíîòóôõùúûç'
    for E, D in fatias:
        for letra in letras:
            novas_palavras.append(E + letra + D)
    return novas_palavras

# %%
def gerador_palavras(palavra):
    fatias = []
    for i in range(len(palavra) + 1):
        fatias.append((palavra[:i], palavra[i:]))
    palavras_geradas = insere_letras(fatias)
    return palavras_geradas

# %%
palavras_geradas = gerador_palavras(palavra_exemplo)
palavras_geradas
# Out:
# ['algica',
#  'blgica',
#  'clgica',
#  'dlgica',
#  'elgica',
#  'flgica',
#  'glgica',
#  'hlgica',
#  'ilgica',
#  'jlgica',
#  'klgica',
#  'llgica',
#  'mlgica',
#  'nlgica',
#  'olgica',
#  'plgica',
#  'qlgica',
#  'rlgica',
#  'slgica',
#  'tlgica',
#  'ulgica',
#  'vlgica',
#  'wlgica',
#  'xlgica',
#  'ylgica',
#  'zlgica',
#  'àlgica',
#  'álgica',
#  'âlgica',
#  'ãlgica',
#  'èlgica',
#  'élgica',
#  'êlgica',
#  'ìlgica',
#  'ílgica',
#  'îlgica',
#  'òlgica',
#  'ólgica',
#  'ôlgica',
#  'õlgica',
#  'ùlgica',
#  'úlgica',
#  'ûlgica',
#  'çlgica',
#  'lagica',
#  'lbgica',
#  'lcgica',
#  'ldgica',
#  'legica',
#  'lfgica',
#  'lggica',
#  'lhgica',
#  'ligica',
#  'ljgica',
#  'lkgica',
#  'llgica',
#  'lmgica',
#  'lngica',
#  'logica',
#  'lpgica',
#  'lqgica',
#  'lrgica',
#  'lsgica',
#  'ltgica',
#  'lugica',
#  'lvgica',
#  'lwgica',
#  'lxgica',
#  'lygica',
#  'lzgica',
#  'làgica',
#  'lágica',
#  'lâgica',
#  'lãgica',
#  'lègica',
#  'légica',
# ...

# %%
total_palavras = len(lista_normalizada)
frequencia = nltk.FreqDist(lista_normalizada)

# %%
def probabilidade(palavra_gerada):
    return frequencia[palavra_gerada]/total_palavras

# %%
def corretor(palavra):
    palavras_geradas = gerador_palavras(palavra)
    palavra_correta = max(palavras_geradas, key=probabilidade)
    return palavra_correta

# %%
palavra_exemplo
# Out:
# 'lgica'

# %%
corretor(palavra_exemplo)
# Out:
# 'lógica'

# %%
def cria_dados_teste(nome_arquivo):
    lista_palavras_teste = []
    f = open(nome_arquivo, "r", encoding = 'utf-8')
    for linha in f:
        correta, errada = linha.split()
        lista_palavras_teste.append((correta, errada))
    f.close()
    return lista_palavras_teste

lista_teste = cria_dados_teste("../corretor-master/palavras.txt")
lista_teste
# Out:
# [('podemos', 'pyodemos'),
#  ('esse', 'esje'),
#  ('já', 'jrá'),
#  ('nosso', 'nossov'),
#  ('são', 'sãêo'),
#  ('dos', 'dosa'),
#  ('muito', 'muifo'),
#  ('imagem', 'iômagem'),
#  ('sua', 'ósua'),
#  ('também', 'tambéùm'),
#  ('ele', 'eme'),
#  ('fazer', 'èazer'),
#  ('temos', 'temfs'),
#  ('essa', 'eàssa'),
#  ('quando', 'quaôdo'),
#  ('vamos', 'vamvos'),
#  ('sobre', 'hsobre'),
#  ('java', 'sjava'),
#  ('das', 'daõs'),
#  ('agora', 'agorah'),
#  ('está', 'eòtá'),
#  ('cada', 'céda'),
#  ('mesmo', 'zmesmo'),
#  ('nos', 'noâ'),
#  ('forma', 'fobma'),
#  ('seja', 'sejéa'),
#  ('então', 'enêão'),
#  ('criar', 'èriar'),
#  ('código', 'cóeigo'),
#  ('caso', 'casío'),
#  ('exemplo', 'áexemplo'),
#  ('tem', 'tĩem'),
#  ('usuário', 'usuárôio'),
#  ('dados', 'dfados'),
#  ('python', 'pgthon'),
#  ('nossa', 'nossah'),
#  ('além', 'alémè'),
#  ('assim', 'asõim'),
#  ('ter', 'teb'),
#  ('até', 'atĩ'),
#  ('bem', 'âem'),
#  ('design', 'desigen'),
#  ('trabalho', 'trabalàho'),
# ...

# %%
def avaliador(testes):
    acertou = 0
    for correta, errada in testes:
        palavra_corrigida = corretor(errada)
        if palavra_corrigida == correta:
            acertou += 1
    numero_palavras = len(testes)
    taxa_acerto = round(acertou * 100/numero_palavras, 2)
    return ("Taxa de acerto de {}% de {} palavras".format(taxa_acerto, numero_palavras))

# %%
corretor_v1 = avaliador(lista_teste)
corretor_v1
# Out:
# 'Taxa de acerto de 1.08% de 186 palavras'

# %%
corretor_v1
# Out:
# 'Taxa de acerto de 1.08% de 186 palavras'

# %%
def deletando_carateres(fatias):
    novas_palavras = []
    for E, D in fatias:
        novas_palavras.append(E + D[1:])
    return novas_palavras

# %%
def gerador_palavras(palavra):
    fatias = []
    for i in range(len(palavra) + 1):
        fatias.append((palavra[:i], palavra[i:]))
    palavras_geradas = insere_letras(fatias)
    palavras_geradas += deletando_carateres(fatias)
    return palavras_geradas

# %%
teste = "lóigica"
palavras_geradas = gerador_palavras(teste)
palavras_geradas
# Out:
# ['alóigica',
#  'blóigica',
#  'clóigica',
#  'dlóigica',
#  'elóigica',
#  'flóigica',
#  'glóigica',
#  'hlóigica',
#  'ilóigica',
#  'jlóigica',
#  'klóigica',
#  'llóigica',
#  'mlóigica',
#  'nlóigica',
#  'olóigica',
#  'plóigica',
#  'qlóigica',
#  'rlóigica',
#  'slóigica',
#  'tlóigica',
#  'ulóigica',
#  'vlóigica',
#  'wlóigica',
#  'xlóigica',
#  'ylóigica',
#  'zlóigica',
#  'àlóigica',
#  'álóigica',
#  'âlóigica',
#  'ãlóigica',
#  'èlóigica',
#  'élóigica',
#  'êlóigica',
#  'ìlóigica',
#  'ílóigica',
#  'îlóigica',
#  'òlóigica',
#  'ólóigica',
#  'ôlóigica',
#  'õlóigica',
#  'ùlóigica',
#  'úlóigica',
#  'ûlóigica',
#  'çlóigica',
#  'laóigica',
#  'lbóigica',
#  'lcóigica',
#  'ldóigica',
#  'leóigica',
#  'lfóigica',
#  'lgóigica',
#  'lhóigica',
#  'lióigica',
#  'ljóigica',
#  'lkóigica',
#  'llóigica',
#  'lmóigica',
#  'lnóigica',
#  'loóigica',
#  'lpóigica',
#  'lqóigica',
#  'lróigica',
#  'lsóigica',
#  'ltóigica',
#  'luóigica',
#  'lvóigica',
# ...

# %%
corretor_v2 = avaliador(lista_teste)
corretor_v2
# Out:
# 'Taxa de acerto de 41.4% de 186 palavras'

# %%
print(corretor_v1)
print(corretor_v2)
# Out:
# Taxa de acerto de 1.08% de 186 palavras
# Taxa de acerto de 41.4% de 186 palavras

# %%
def deletando_caracteres(fatias):
    novas_palavras = []
    for E, D in fatias:
        novas_palavras.append(E + D[1:])
    return novas_palavras

def insere_letras(fatias):
    novas_palavras = []
    letras = 'abcdefghijklmnopqrstuvwxyzàáâãèéêìíîòóôõùúûç'
    for E, D in fatias:
        for letra in letras:
            novas_palavras.append(E + letra + D)
    return novas_palavras

def troca_letra(fatias):
    novas_palavras = []
    letras = 'abcdefghijklmnopqrstuvwxyzàáâãèéêìíîòóôõùúûç'
    for E, D in fatias:
        for letra in letras:
                novas_palavras.append(E + letra + D[1:])
    return novas_palavras

def inverte_letra(fatias):
    novas_palavras = []
    for E, D in fatias:
        if len(D) > 1:
            novas_palavras.append(E + D[1] + D[0] + D[2:])
    return novas_palavras

def gerador_palavras(palavra):
    fatias = []
    for i in range(len(palavra) + 1):
        fatias.append((palavra[:i], palavra[i:]))
    palavras_geradas = insere_letras(fatias)
    palavras_geradas += deletando_caracteres(fatias)
    palavras_geradas += troca_letra(fatias)
    palavras_geradas += inverte_letra(fatias)
    return palavras_geradas

# %%
teste = "lógiac"
palavras_geradas = gerador_palavras(teste)
palavras_geradas
# Out:
# ['alógiac',
#  'blógiac',
#  'clógiac',
#  'dlógiac',
#  'elógiac',
#  'flógiac',
#  'glógiac',
#  'hlógiac',
#  'ilógiac',
#  'jlógiac',
#  'klógiac',
#  'llógiac',
#  'mlógiac',
#  'nlógiac',
#  'ológiac',
#  'plógiac',
#  'qlógiac',
#  'rlógiac',
#  'slógiac',
#  'tlógiac',
#  'ulógiac',
#  'vlógiac',
#  'wlógiac',
#  'xlógiac',
#  'ylógiac',
#  'zlógiac',
#  'àlógiac',
#  'álógiac',
#  'âlógiac',
#  'ãlógiac',
#  'èlógiac',
#  'élógiac',
#  'êlógiac',
#  'ìlógiac',
#  'ílógiac',
#  'îlógiac',
#  'òlógiac',
#  'ólógiac',
#  'ôlógiac',
#  'õlógiac',
#  'ùlógiac',
#  'úlógiac',
#  'ûlógiac',
#  'çlógiac',
#  'laógiac',
#  'lbógiac',
#  'lcógiac',
#  'ldógiac',
#  'leógiac',
#  'lfógiac',
#  'lgógiac',
#  'lhógiac',
#  'liógiac',
#  'ljógiac',
#  'lkógiac',
#  'llógiac',
#  'lmógiac',
#  'lnógiac',
#  'loógiac',
#  'lpógiac',
#  'lqógiac',
#  'lrógiac',
#  'lsógiac',
#  'ltógiac',
#  'luógiac',
#  'lvógiac',
#  'lwógiac',
#  'lxógiac',
#  'lyógiac',
#  'lzógiac',
#  'làógiac',
# ...

# %%
corretor_v3 = avaliador(lista_teste)
corretor_v3
# Out:
# 'Taxa de acerto de 76.34% de 186 palavras'

# %%
print(corretor_v1)
print(corretor_v2)
print(corretor_v3)
# Out:
# Taxa de acerto de 1.08% de 186 palavras
# Taxa de acerto de 41.4% de 186 palavras
# Taxa de acerto de 76.34% de 186 palavras

# %%
def avaliador(testes, vocabulario):
    acertou = 0
    desconhecida = 0
    for correta, errada in testes:
        palavra_corrigida = corretor(errada)
        if palavra_corrigida == correta:
            acertou += 1
        else:
            desconhecida += (correta not in vocabulario)
    numero_palavras = len(testes)
    taxa_acerto = round(acertou * 100/numero_palavras, 2)
    taxa_desconhecida = round(desconhecida * 100/numero_palavras, 2)
    return ("Taxa de acerto de {}% de {} palavras e uma taxa de {} palavras desconhecidas".format(taxa_acerto, numero_palavras, taxa_desconhecida))

# %%
vocabulario = set(lista_normalizada)

# %%
avaliador(lista_teste, vocabulario)
# Out:
# 'Taxa de acerto de 76.34% de 186 palavras e uma taxa de 6.99 palavras desconhecidas'

# %%
palavra = 'lóiigica'

def gerador_turbinado(palavras_geradas):
    novas_palavras = []
    for palavra in palavras_geradas:
        novas_palavras += gerador_palavras(palavra)
    return novas_palavras

# %%
palavras_g = gerador_turbinado(gerador_palavras(palavra))
'lógica'in palavras_g
# Out:
# True

# %%
len(palavras_g)
# Out:
# 691744

# %%
def novo_corretor(palavra):
    palavras_geradas = gerador_palavras(palavra)
    palavras_geradas_turbinado = gerador_turbinado(palavras_geradas)
    todas_palavras = set(palavras_geradas + palavras_geradas_turbinado)
    candidatos = [palavra]
    for palavra in todas_palavras:
        if palavra in vocabulario:
            candidatos.append(palavra)
    palavra_correta = max(candidatos, key=probabilidade)
    return palavra_correta

# %%
novo_corretor(palavra)
# Out:
# 'lógica'

# %%
def avaliador(testes, vocabulario):
    acertou = 0
    desconhecida = 0
    for correta, errada in testes:
        palavra_corrigida = novo_corretor(errada)
        if palavra_corrigida == correta:
            acertou += 1
        else:
            desconhecida += (correta not in vocabulario)
    numero_palavras = len(testes)
    taxa_acerto = round(acertou * 100/numero_palavras, 2)
    taxa_desconhecida = round(desconhecida * 100/numero_palavras, 2)
    return ("Taxa de acerto de {}% de {} palavras e uma taxa de {} palavras desconhecidas".format(taxa_acerto, numero_palavras, taxa_desconhecida))

# %%
corretor_v4 = avaliador(lista_teste, vocabulario)
corretor_v4
# Out:
# 'Taxa de acerto de 55.38% de 186 palavras e uma taxa de 6.45 palavras desconhecidas'

# %%
def avaliador(testes, vocabulario):
    acertou = 0
    desconhecida = 0
    for correta, errada in testes:
        palavra_corrigida = novo_corretor(errada)
        desconhecida += (correta not in vocabulario)
        if palavra_corrigida == correta:
            acertou += 1
        else:
            print(errada + '-' + corretor(errada) + '-' + palavra_corrigida)
    numero_palavras = len(testes)
    taxa_acerto = round(acertou * 100/numero_palavras, 2)
    taxa_desconhecida = round(desconhecida * 100/numero_palavras, 2)
    return ("Taxa de acerto de {}% de {} palavras e uma taxa de {} palavras desconhecidas".format(taxa_acerto, numero_palavras, taxa_desconhecida))

# %%
corretor_v5 = avaliador(lista_teste, vocabulario)
corretor_v5
# Out:
# esje-esse-se
# sãêo-são-não
# dosa-dos-do
# eme-em-de
# eàssa-essa-esse
# daõs-das-da
# céda-cada-da
# noâ-no-o
# enêão-então-não
# tĩem-tem-em
# nossah-nossa-nosso
# teb-tem-de
# atĩ-até-a
# âem-em-de
# foo-foi-o
# serr-ser-se
# entke-entre-então
# van-vai-a
# çeus-seus-seu
# eû-e-de
# temeo-tempo-temos
# semre-sempre-ser
# elaá-ela-ele
# síó-só-se
# siàe-site-se
# seém-sem-em
# peln-pelo-ele
# aléra-alura-agora
# tdia-dia-da
# tuúo-tudo-tipo
# jé-é-de
# sãô-são-não
# odos-dos-do
# siua-sua-seu
# elpe-ele-esse
# teos-temos-os
# eũsa-essa-esse
# vjmos-vamos-temos
# dms-dos-de
# cava-java-para
# ános-nos-no
# èaso-caso-as
# túem-tem-em
# daáos-dados-dos
# nossk-nosso-nosso
# tãer-ter-ser
# vté-até-é
# búm-bem-um
# sçerá-será-ser
# entró-entre-então
# uai-vai-a
# sâus-seus-seu
# ìeu-seu-de
# fual-qual-sua
# elal-ela-ele
# skó-só-se
# secm-sem-em
# aluéa-alura-além
# dil-dia-de
# sód-só-se
# eúaa-aeúaa-essa
# ró-só-de
# dĩaz-adĩaz-da
# correptor-corretor-correto
# trtica-tática-prática
# ...

# %%
def avaliador(testes, vocabulario):
    acertou = 0
    desconhecida = 0
    for correta, errada in testes:
        palavra_corrigida = corretor(errada)
        desconhecida += (correta not in vocabulario)
        if palavra_corrigida == correta:
            acertou += 1
    numero_palavras = len(testes)
    taxa_acerto = round(acertou * 100/numero_palavras, 2)
    taxa_desconhecida = round(desconhecida * 100/numero_palavras, 2)
    return ("Taxa de acerto de {}% de {} palavras e uma taxa de {} palavras desconhecidas".format(taxa_acerto, numero_palavras, taxa_desconhecida))

# %%
corretor_v6 = avaliador(lista_teste, vocabulario)
corretor_v6
# Out:
# 'Taxa de acerto de 76.34% de 186 palavras e uma taxa de 6.99 palavras desconhecidas'

# %%
print(corretor_v1)
print(corretor_v2)
print(corretor_v3)
print(corretor_v4)
print(corretor_v5)
print(corretor_v6)
# Out:
# Taxa de acerto de 1.08% de 186 palavras
# Taxa de acerto de 41.4% de 186 palavras
# Taxa de acerto de 76.34% de 186 palavras
# Taxa de acerto de 55.38% de 186 palavras e uma taxa de 6.45 palavras desconhecidas
# Taxa de acerto de 55.38% de 186 palavras e uma taxa de 6.99 palavras desconhecidas
# Taxa de acerto de 76.34% de 186 palavras e uma taxa de 6.99 palavras desconhecidas
